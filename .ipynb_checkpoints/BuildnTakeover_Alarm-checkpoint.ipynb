# %%
#####build alarm완성#####
import random
import time
from threading import Timer
import threading
import os
import re
from pyautogui import press, typewrite, hotkey

#로그인시 얻은 아이디 변수
global id_1
global id_2
global id_3
global id_4
id_1 = 'p1'
id_2 = 'p2'
id_3 = 'p3'
id_4 = 'p4'
global id_list
global id_1_info
id_1_info = [id_1, 10000, 20000, 0]
id_list = [id_1, id_2, id_3, id_4]
#현재 진행중인 플레이어의 배열 임시 설정 (차례가 끝나면 다음 차례의 배열로 바꿈)
global id_now_info
#위에서 1번 플레이어 차례로 왔다고 가정
id_now_info = id_1_info
global now_order
now_order = 0

####여기서부터 새로운 변수입니다.
global now_buildnum
now_buildnum = 0 #현재 매매가 번호 -> 이거 매입이나 매매나 가격은 같죠??
global land_fee #매매가 배열
land_fee=[500, 500, 500, 500, 1000, 1000, 1000, 1000, 1500, 1500, 1500, 1500, 2000, 2000, 2000, 2000] 


def get_player_city():
    global id_list
    global now_order
    global player_input
    global something
    temp = player_input
    player_input = input(id_list[now_order]+' > ')
    if temp != player_input:
        something = True
## 문제없음

def build_error(player_input):
    global now_order
    #global default_map_name
    global owner_list
    global now_build
    player_input = player_input.lower()
    b_res = bool (re.search(" " , player_input))

    if(player_input.isspace() or player_input==""): 
        # 입력에 공백만 있다면
        print("[Error]: 인자의 개수가 적습니다. 1개의 인자를 입력해주세요.")
        return False

    elif(b_res):
        #문자열 사이에 공백이 있다면
        print("[Error]: 인자의 개수가 많습니다. 1개의 인자를 입력해주세요.")
        return False
            
    else:
        # 문자열에 공백 없으면
        if(player_input=="yes" or player_input=="네" or player_input=="o"or
            player_input=="ㅇㅇ" or player_input=="y"or player_input=="ㅇ"):
            print("====== 건설을 진행합니다 ======")
            id_now_info[1]-=land_fee[now_buildnum] #여긴 어떻게 처리해야하지->돈 지불
            # 건설 진행 액션 코드
            build_flag = False
            return True

        elif(player_input=="no" or player_input=="아니오" or player_input=="아니요" or player_input=="x"
            or player_input== "ㄴㄴ" or player_input== "n" or player_input=="ㄴ"):
            print("====== 매입을 포기합니다 ======")
            # 건설 포기 액션 코드
            build_flag = False
            return True
        
        else:
            print("[Error]: 인자에 올바르지 않은 입력값이 들어왔습니다.")
            return False
            # yes, no 동의어 축약형 표 출력
            
def input_timer_build(left_time):
    global player_input
    global now_order
    global id_list
    global something
    something = False
    
    player_input=[None]
    input_timer_build= threading.Thread(target=get_player_city) #이거 혹시 입력 나타내는 함수인가요?
    input_timer_build.daemon = True

    input_timer_build.start() 
    for i in range(1, left_time):     
        if something:     
            something = False
            return build_error(player_input)
        elif player_input[0] != None:
            player_input=[None]
            input_timer_build= threading.Thread(target=get_player_city)
            input_timer_build.daemon = True
            input_timer_build.start()
        time.sleep(1)
        
    if player_input[0] == None:
        press('Enter')
        player_input=[None]
        print('===== %d초가 지났습니다. =====' % left_time)
        if(left_time == 10):
            print('===== 중도포기 하였습니다. =====')
            time.sleep(2)
            
            # 중도포기 함수 자리
            id_info_list[now_order][3] = 2
            return True
        else:
            print('===== 경고 1회 받았습니다. =====')
            print("====== 매입을 포기합니다 ======")
            build_flag = False
            time.sleep(2)
            return True
            # 경고 함수 자리
    else:
        time.sleep(2)


        

def build():
    # 보유중인 도시 없으면 넘어가는걸
    global build_flag 
    build_flag = True # 매입 선택 가능한 상태
    if(id_now_info[1]>100): #여기서 매매가 설정
        while 1:
            if(build_flag):
                print('>> build?')
                if input_timer_build(15):
                    return

    else:
        print("[Error]: 매입을 진행할 돈이 부족합니다. 매입을 포기합니다.")
        build_flag = False
        
build()
# Out:
# >> build?
# p1 >
# ===== 15초가 지났습니다. =====
# ===== 경고 1회 받았습니다. =====
# ====== 매입을 포기합니다 ======

# %%
# 인수가 배열
global take_fee
take_fee = [500, 500, 500, 500, 1000, 1000, 1000, 1000, 1500, 1500, 1500, 1500, 2000, 2000, 2000, 2000] #기획서_데이터파일 참고
global now_takeovernum
now_takeovernum = 0 #현재 인수가 번호
def get_player_takeover():
    global id_list
    global now_order
    global player_input
    global something
    temp = player_input
    player_input = input(id_list[now_order]+' > ')
    if temp != player_input:
        something = True
## 문제없음

def takeover_error(player_input):
    global now_order
    global owner_list
    global now_takeover
    player_input = player_input.lower()
    t_res = bool (re.search(" " , player_input))

    if(player_input.isspace() or player_input==""): 
        # 입력에 공백만 있다면
        print("[Error]: 인자의 개수가 적습니다. 1개의 인자를 입력해주세요.")
        return False

    elif(t_res):
        #문자열 사이에 공백이 있다면
        print("[Error]: 인자의 개수가 많습니다. 1개의 인자를 입력해주세요.")
        return False
            
    else:
        # 문자열에 공백 없으면

        if(player_input=="yes" or player_input=="네" or player_input=="o"or
            player_input=="ㅇㅇ" or player_input=="y"or player_input=="ㅇ"):

            print("====== 인수를 진행합니다 ======")
            id_now_info[1]-=take_fee[now_takeovernum] #자산차감
            # 인수 진행 액션 코드
            takeover_flag = False
            return True

        
        elif(player_input=="no" or player_input=="아니오" or player_input=="아니요" or player_input=="x"
            or player_input== "ㄴㄴ" or player_input== "n" or player_input=="ㄴ"):
            print("====== 인수를 포기합니다 ======")
            # 건설 포기 액션 코드
            takeover_flag = False
            return True
        
        else:
            print("[Error]: 인자에 올바르지 않은 입력값이 들어왔습니다.")
            return False
            # yes, no 동의어 축약형 표 출력
                

def input_timer_takeover(left_time):
    global player_input
    global now_order
    global id_list
    global something
    something = False
    
    player_input=[None]
    input_timer_takeover= threading.Thread(target=get_player_takeover) #이거 혹시 입력 나타내는 함수인가요?
    input_timer_takeover.daemon = True

    input_timer_takeover.start() 
    for i in range(1, left_time):     
        if something:     
            something = False
            return takeover_error(player_input)
        elif player_input[0] != None:
            player_input=[None]
            input_timer_takeover= threading.Thread(target=get_player_takeover)
            input_timer_takeover.daemon = True
            input_timer_takeover.start()
        time.sleep(1)
        
    if player_input[0] == None:
        press('Enter')
        player_input=[None]
        print('===== %d초가 지났습니다. =====' % left_time)
        if(left_time == 10):
            print('===== 중도포기 하였습니다. =====')
            time.sleep(2)
            
            # 중도포기 함수 자리
            id_info_list[now_order][3] = 2
            return True
        else:
            print('===== 경고 1회 받았습니다. =====')
            time.sleep(2)
            takeover_flag = False
            return True
            # 경고 함수 자리
    else:
        time.sleep(2)


#축제 함수
def takeover():
    global takeover_flag 
    takeover_flag = True # 인수 가능한 flag값
    if(id_now_info[1]>land_fee[now_takeovernum]): #여기서 인수가 설정
        while 1:
            if(takeover_flag):
                print('>> takeover?')
                if input_timer_takeover(15):
                    return
    else:
        print("[Error]: 인수를 진행할 돈이 부족합니다. 인수를 포기합니다.")
        takeover_flag = False
         
        
takeover()
# Out:
# >> takeover?
# p1 >
# ===== 15초가 지났습니다. =====
# ===== 중도포기 하였습니다. =====
